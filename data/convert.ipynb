# %%
import pandas as pd
import xlrd

# %%
df = pd.read_excel("Master List_AdvancingProjects.xlsx")

# %%
df.head()
# Out:
#               Project Status  1st Review  2nd Review  Average Score  \
# 0  Advance to Further Review          18        16.0           17.0
# 1  Advance to Further Review          20        20.0           20.0
# 2  Advance to Further Review          16        16.0           16.0
# 3  Advance to Further Review          15        18.0           16.5
# 4  Advance to Further Review          20        17.0           18.5
#
#   Initial Review Notes Project # Project Combined  \
# 0                  NaN    17-006              NaN
# 1                  NaN    17-014              NaN
# 2                  NaN    17-019              NaN
# 3                  NaN    17-031              NaN
# 4                  NaN    17-044              NaN
#
#                                        Project Title  \
# 0                  Trail improvements @ Roxhill Park
# 1  Improve 5-way intersection @ Dallas Ave S, 12t...
# 2                  Busstop improvements on Barton St
# ...

# %%
df.columns = ['status', 'review1', 'review2', 'avg','initial', 'no','combined', 'title', 'need', 'idea','latitude', 'longitude', 'location', 'type', 'dept','benefits', 'dist', 'neigh']

# %%
df.head()
# Out:
#                       status  review1  review2   avg initial      no combined  \
# 0  Advance to Further Review       18     16.0  17.0     NaN  17-006      NaN
# 1  Advance to Further Review       20     20.0  20.0     NaN  17-014      NaN
# 2  Advance to Further Review       16     16.0  16.0     NaN  17-019      NaN
# 3  Advance to Further Review       15     18.0  16.5     NaN  17-031      NaN
# 4  Advance to Further Review       20     17.0  18.5     NaN  17-044      NaN
#
#                                                title  \
# 0                  Trail improvements @ Roxhill Park
# 1  Improve 5-way intersection @ Dallas Ave S, 12t...
# 2                  Busstop improvements on Barton St
# 3         Crossing Improvement along SW Henderson St
# 4               Improved crossings on S. Cloverdale
#
#                                                 need  \
# 0  Trail improvements at Roxhill Park - violence ...
# 1  A traffic calming mechanism is much needed at ...
# ...

# %%
out = df.iloc[0:10].to_json(orient='records')
outAll = df.to_json(orient='records')

# %%
with open('proposals.json', 'w') as f:
    f.write(out)

# %%
with open('allProposals.json', 'w') as f:
    f.write(outAll)
